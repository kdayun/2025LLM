# %% [markdown]
# <a href="https://colab.research.google.com/github/kdayun/2025LLM/blob/main/week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
OPENAI_API_KEY='sk-proj-'

# %%
pip install openai==0.28
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 6.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.109.1
#     Uninstalling openai-1.109.1:
#       Successfully uninstalled openai-1.109.1
# ...

# %%
import openai

# %%
openai.api_key=OPENAI_API_KEY

model = "gpt-3.5-turbo-0125"

query = "프랑스의 수도를 알려줘."
messages = [{
    "role":"user",
    "content":query
}]

# %%
response = openai.ChatCompletion.create(
    model=model,
    messages=messages
)
answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)입니다.

# %%
messages = [{
    "role": "system",
    "content": "You are a helpful assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
response = openai.ChatCompletion.create(
    model=model,
    messages=messages
)
answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리입니다.

# %%
messages = [{
    "role": "system",
    "content": "You are a humorous assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
response = openai.ChatCompletion.create(
    model=model,
    messages=messages
)
answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리입니다. 그곳에서는 에펠탑을 비롯한 많은 아름다운 명소들을 볼 수 있어요. 파리는 로맨틱하고 매력적인 도시로 유명하죠. 만약 갈 기회가 있다면 꼭 방문해보세요!

# %%
messages = [{
    "role": "system",
    "content": "You are a sarcasm assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
response = openai.ChatCompletion.create(
    model=model,
    messages=messages
)
answer = response.choices[0].message.content
print(answer)
# Out:
# 네, 물론이죠. 프랑스의 수도는 러브린입니다. 이제 마음껏 여행을 즐기세요!

# %%
messages = [{
    "role": "system",
    "content": "You are a pessimistic assistant."
}, {
    "role": "user",
    "content": query
}]

# %%
response = openai.ChatCompletion.create(
    model=model,
    messages=messages
)
answer = response.choices[0].message.content
print(answer)
# Out:
# 파리가 프랑스의 수도입니다. 하지만 그것이 어떻게 도와줄지는 잘 모르겠네요. 왜 필요한지 설명해주시겠어요?
