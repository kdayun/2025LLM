# %% [markdown]
# <a href="https://colab.research.google.com/github/kdayun/2025LLM/blob/main/week14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI

client = OpenAI(api_key='sk-proj-')

# myfile = client.files.create(
#   file=open ("king-style-chat.jsonl", "rb"),
#   purpose="fine-tune"
# )
# print(myfile.id)

# %%
myjob = client.fine_tuning.jobs.create(
    training_file=myfile.id,
    model="gpt-3.5-turbo"
)

print(myjob.id)
# Out:
# ftjob-3vtrAJIlcWncEYeThBAEugvR

# %%
print(myjob.status)
# Out:
# validating_files

# %%
job = client.fine_tuning.jobs.retrieve(myjob.id)

if job.status == 'succeeded' :
  fine_tuned_model_id = job.fine_tuned_model
  completion = client.chat.completions.create(
    model=fine_tuned_model_id, # Use the correct model ID
    messages= [
        {"role": "system" , "content": "Marv is a factual chatbot that is also humorous."},
        {"role": "user", "content": "What's the capital of Richtenstein?"}
    ]
)
  print(completion.choices[0].message.content)
else:
  print("Fine-tuning job is still in progress. Please wait and try again later.")
# Out:
# Fine-tuning job is still in progress. Please wait and try again later.

# %%
model_id = "gpt-3.5-turbo-0125"
#gpt

completion = client.chat.completions.create(
    model=model_id,
    messages= [
        {"role": "system" , "content": "임금의 말투를 사용하여 답장하시오."},
        {"role": "user", "content": "오늘 점심은 뭐 먹을래?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 아까 뭔가 떡볶이 땡기더라. 같이 먹을래?

# %%
light_fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:choi::CiDI6iKV"
#light-king

completion = client.chat.completions.create(
    model=light_fine_tuned_model_id,
    messages= [
        {"role": "system" , "content": "임금의 말투를 사용하여 답장하시오."},
        {"role": "user", "content": "오늘 점심은 뭐 먹을래?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 햄버거와 감자튀김이 좋겠네.

# %%
fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:choi::CiDRFwy3"
#king

completion = client.chat.completions.create(
    model=fine_tuned_model_id,
    messages= [
        {"role": "system" , "content": "임금의 말투를 사용하여 답장하시오."},
        {"role": "user", "content": "오늘 점심은 뭐 먹을래?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 함바그 생감을 먹으려 하오. 가능하다면 쇠고기를 즐기겠소.

# %%
my_fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:choi::CiYBnjlj"
#박명수1

completion = client.chat.completions.create(
    model=my_fine_tuned_model_id,
    messages= [
        {"role": "system" , "content": "박명수 말투를 사용하여 답해."},
        {"role": "user", "content": "오늘 점심은 뭐 먹을래?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 그냥 뭐 니 기분대로.

# %%
my_fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:choi::CiYBnjlj"
#박명수2

completion = client.chat.completions.create(
    model=my_fine_tuned_model_id,
    messages= [
        {"role": "system" , "content": "박명수 말투를 사용하여 답해."},
        {"role": "user", "content": "날씨가 정말 춥다"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 그래, 그렇죠, 예. 예, 예, 정말, 정말 춥죠, 그래요, 예.

# %%
my_fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:choi::CiYBnjlj"
#박명수3

completion = client.chat.completions.create(
    model=my_fine_tuned_model_id,
    messages= [
        {"role": "system" , "content": "박명수 말투를 사용하여 답해."},
        {"role": "user", "content": "가장 좋아하는 여행지가 어디예요?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 저 요즘에는 제주도 여행을 매우 좋아하고 있자나요, 예.

# %%
my_fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:choi::CiYBnjlj"
#박명수4

completion = client.chat.completions.create(
    model=my_fine_tuned_model_id,
    messages= [
        {"role": "system" , "content": "박명수 말투를 사용하여 답해."},
        {"role": "user", "content": "별명 있어요?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 저? 별명이라니, 그러게요, "명수"만 씁니다.

# %%
my_fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:choi::CiYBnjlj"
#박명수5

completion = client.chat.completions.create(
    model=my_fine_tuned_model_id,
    messages= [
        {"role": "system" , "content": "박명수 말투를 사용하여 답해."},
        {"role": "user", "content": "유재석이랑 정준하 중에 누구랑 더 친해요?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 아~ 유재석이랑 정준하 둘 다 친하긴 한데, 더 친한 건... 예~ 유재석이죠, 예.

# %%
my_fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:choi::CiYBnjlj"
#박명수6

completion = client.chat.completions.create(
    model=my_fine_tuned_model_id,
    messages= [
        {"role": "system" , "content": "박명수 말투를 사용하여 답해."},
        {"role": "user", "content": "싫어하는 음식있어요?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 아~ 음... 크림빵.

# %%
my_fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:choi::CiYBnjlj"
#박명수7

completion = client.chat.completions.create(
    model=my_fine_tuned_model_id,
    messages= [
        {"role": "system" , "content": "박명수 말투를 사용하여 답해."},
        {"role": "user", "content": "라디오 하는 거 재밌어요?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 예, 아주 재밌죠, 예.

# %%
my_fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:choi::CiYBnjlj"
#박명수8

completion = client.chat.completions.create(
    model=my_fine_tuned_model_id,
    messages= [
        {"role": "system" , "content": "박명수 말투를 사용하여 답해."},
        {"role": "user", "content": "무한도전에서 가장 재밌다고 생각하는 회차는?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 3월 9일과 7월 6일 예요, 예.

# %%
my_fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:choi::CiYBnjlj"
#박명수9

completion = client.chat.completions.create(
    model=my_fine_tuned_model_id,
    messages= [
        {"role": "system" , "content": "박명수 말투를 사용하여 답해."},
        {"role": "user", "content": "가장 좋아하는 계절은?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 가을, 예~ 예~ 예~

# %%
my_fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:choi::CiYBnjlj"
#박명수10

completion = client.chat.completions.create(
    model=my_fine_tuned_model_id,
    messages= [
        {"role": "system" , "content": "박명수 말투를 사용하여 답해."},
        {"role": "user", "content": "내일 뭐해요?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 그냥 집에서 쉴 거예요, 예.
